# %% [markdown]
# # Lista de Exercícios — Módulo 1
#
# **Curso:** Python para Ciência de Dados
# **Disciplina:** Ciência de Dados (T326) — UNIFOR
#
# Resolva cada exercício na célula indicada. O gabarito está no arquivo `gabarito_modulo1.ipynb`.

# %% [markdown]
# ---
# ### Exercício 1 — Variáveis e f-string
#
# Crie três variáveis: `nome` (str), `idade` (int) e `altura` (float).
# Exiba a seguinte frase usando f-string:
#
# ```
# Meu nome e [nome], tenho [idade] anos e [altura]m de altura.
# ```

# %%
# Exercício 1

# %% [markdown]
# ---
# ### Exercício 2 — Condicional
#
# Dada uma nota, exiba a situação do aluno:
#
# - Nota >= 7: `Aprovado`
# - Nota >= 5: `Recuperacao`
# - Nota < 5: `Reprovado`
#
# Teste com os valores 8.0, 5.5 e 3.0.

# %%
# Exercício 2

# %% [markdown]
# ---
# ### Exercício 3 — Laço for
#
# Some todos os números inteiros de 1 a 100 usando um laço `for`.
# Exiba o resultado no formato: `Soma: 5050`

# %%
# Exercício 3

# %% [markdown]
# ---
# ### Exercício 4 — Lista com enumerate
#
# Crie uma lista com 5 cidades brasileiras.
# Usando `enumerate()`, exiba cada cidade com seu número de ordem:
#
# ```
# 1. Fortaleza
# 2. Sao Paulo
# ...
# ```

# %%
# Exercício 4

# %% [markdown]
# ---
# ### Exercício 5 — Dicionário
#
# Crie um dicionário chamado `aluno` com as chaves: `nome`, `idade`, `curso` e `nota`.
# Exiba cada campo em uma linha separada no formato `chave: valor`.

# %%
# Exercício 5

# %% [markdown]
# ---
# ### Exercício 6 — Filtro com condicional
#
# Dada a lista abaixo, exiba apenas os números maiores que 5.
#
# ```python
# numeros = [3, 7, 2, 9, 1, 5, 8, 4, 6]
# ```

# %%
# Exercício 6
numeros = [3, 7, 2, 9, 1, 5, 8, 4, 6]

# %% [markdown]
# ---
# ### Exercício 7 — Função
#
# Crie uma função chamada `celsius_para_fahrenheit(c)` que converte uma temperatura de Celsius para Fahrenheit.
#
# Fórmula: `F = C * 9/5 + 32`
#
# Teste a função com os valores 0, 100 e 37 graus.

# %%
# Exercício 7

# %% [markdown]
# ---
# ### Exercício 8 — Lista de dicionários
#
# Dada a lista abaixo, encontre e exiba o nome do aluno com a maior nota.
#
# ```python
# turma = [
#     {"nome": "Ana",   "nota": 9.0},
#     {"nome": "Bruno", "nota": 7.5},
#     {"nome": "Carol", "nota": 8.0},
#     {"nome": "Diego", "nota": 6.5},
# ]
# ```

# %%
# Exercício 8
turma = [
    {"nome": "Ana",   "nota": 9.0},
    {"nome": "Bruno", "nota": 7.5},
    {"nome": "Carol", "nota": 8.0},
    {"nome": "Diego", "nota": 6.5},
]
